# %% [markdown]
# # 05 - Advanced Medical Denoising
# Compare iterative TV denoising and wavelet denoising for medical images.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.pipeline import run_medical_comparison

# %%
run_medical_comparison(project_root / 'images' / 'medical' / 'ultrasound', limit=3)

# %%
run_medical_comparison(project_root / 'images' / 'medical' / 'xray', limit=2)
