# %% [markdown]
# # 04 - Adaptive Noise Handling Pipeline
# Use heuristic noise detection to choose denoising operations automatically.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.pipeline import run_basic_folder

# %%
run_basic_folder(project_root / 'images' / 'random', noise_type=None, limit=4)

# %%
run_basic_folder(project_root / 'images' / 'medical' / 'xray', noise_type=None, limit=3)

# %%
run_basic_folder(project_root / 'images' / 'medical' / 'ultrasound', noise_type=None, limit=3)

# %%
run_basic_folder(project_root / 'images' / 'random', noise_type=None, limit=3)
